# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf

# %%
# --- Define Parameters ---

LOG_DIR = './logs'
TIMESTEPS = 5
RNN_UNITS = 50  # Number of units in the LSTM layer
DENSE_LAYERS = [10, 10]
TRAINING_STEPS = 100
BATCH_SIZE = 100
PRINT_STEPS = TRAINING_STEPS // 10
LEARNING_RATE = 0.03

# --- Generate Data ---

def generate_data(fct, x, timesteps, seperate=False):
    data = fct(x)
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    split1 = int(0.6 * len(X))
    split2 = int(0.8 * len(X))
    return {
        'train': np.array(X[:split1]),
        'val': np.array(X[split1:split2]),
        'test': np.array(X[split2:])
    }, {
        'train': np.array(y[:split1]),
        'val': np.array(y[split1:split2]),
        'test': np.array(y[split2:])
    }

X, y = generate_data(np.sin, np.linspace(0, 100, 10000), TIMESTEPS)

# %%
# --- Build LSTM Model ---

def build_lstm_model(timesteps, rnn_units, dense_layers):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(timesteps, 1)))
    model.add(tf.keras.layers.LSTM(rnn_units))
    for units in dense_layers:
        model.add(tf.keras.layers.Dense(units, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=LEARNING_RATE),
                  loss='mse',
                  metrics=['mae'])
    return model

# Reshape input for LSTM (samples, timesteps, features)
X_train = X['train'][..., np.newaxis]
X_val = X['val'][..., np.newaxis]
X_test = X['test'][..., np.newaxis]

# --- Create Model ---

model = build_lstm_model(TIMESTEPS, RNN_UNITS, DENSE_LAYERS)

# --- Setup EarlyStopping ---

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# --- Train Model ---

history = model.fit(
    X_train, y['train'],
    validation_data=(X_val, y['val']),
    epochs=TRAINING_STEPS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stopping],
    verbose=2
)

# --- Evaluate Model ---

predicted = model.predict(X_test).flatten()
mse = mean_squared_error(y['test'], predicted)
print(f"Error (MSE): {mse:.6f}")

# --- Plot Predictions ---

plt.figure(figsize=(12, 6))
plt.plot(predicted, label='Predicted')
plt.plot(y['test'], label='Actual')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 60/60 - 1s - 11ms/step - loss: 0.1058 - mae: 0.2106 - val_loss: 0.0042 - val_mae: 0.0529
# Epoch 2/100
# 60/60 - 0s - 2ms/step - loss: 0.0027 - mae: 0.0413 - val_loss: 0.0019 - val_mae: 0.0343
# Epoch 3/100
# 60/60 - 0s - 2ms/step - loss: 0.0015 - mae: 0.0300 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 4/100
# 60/60 - 0s - 2ms/step - loss: 0.0011 - mae: 0.0264 - val_loss: 0.0010 - val_mae: 0.0255
# Epoch 5/100
# 60/60 - 0s - 2ms/step - loss: 9.2531e-04 - mae: 0.0246 - val_loss: 8.6131e-04 - val_mae: 0.0238
# Epoch 6/100
# 60/60 - 0s - 2ms/step - loss: 8.1182e-04 - mae: 0.0233 - val_loss: 7.5693e-04 - val_mae: 0.0223
# Epoch 7/100
# 60/60 - 0s - 2ms/step - loss: 7.3034e-04 - mae: 0.0223 - val_loss: 6.9343e-04 - val_mae: 0.0213
# Epoch 8/100
# 60/60 - 0s - 2ms/step - loss: 6.5340e-04 - mae: 0.0213 - val_loss: 6.1446e-04 - val_mae: 0.0202
# Epoch 9/100
# 60/60 - 0s - 2ms/step - loss: 6.0025e-04 - mae: 0.0205 - val_loss: 5.7544e-04 - val_mae: 0.0202
# Epoch 10/100
# 60/60 - 0s - 2ms/step - loss: 5.5673e-04 - mae: 0.0198 - val_loss: 5.2031e-04 - val_mae: 0.0190
# Epoch 11/100
# 60/60 - 0s - 2ms/step - loss: 5.2297e-04 - mae: 0.0193 - val_loss: 5.1345e-04 - val_mae: 0.0186
# Epoch 12/100
# 60/60 - 0s - 2ms/step - loss: 4.9219e-04 - mae: 0.0187 - val_loss: 4.7382e-04 - val_mae: 0.0186
# Epoch 13/100
# 60/60 - 0s - 2ms/step - loss: 4.7319e-04 - mae: 0.0184 - val_loss: 4.6693e-04 - val_mae: 0.0183
# Epoch 14/100
# 60/60 - 0s - 2ms/step - loss: 4.5961e-04 - mae: 0.0182 - val_loss: 4.5562e-04 - val_mae: 0.0178
# Epoch 15/100
# 60/60 - 0s - 2ms/step - loss: 4.4896e-04 - mae: 0.0181 - val_loss: 4.6556e-04 - val_mae: 0.0185
# Epoch 16/100
# 60/60 - 0s - 2ms/step - loss: 4.3396e-04 - mae: 0.0179 - val_loss: 4.2654e-04 - val_mae: 0.0177
# Epoch 17/100
# 60/60 - 0s - 2ms/step - loss: 4.2352e-04 - mae: 0.0178 - val_loss: 4.0241e-04 - val_mae: 0.0173
# Epoch 18/100
# 60/60 - 0s - 2ms/step - loss: 4.1714e-04 - mae: 0.0177 - val_loss: 3.9989e-04 - val_mae: 0.0176
# Epoch 19/100
# 60/60 - 0s - 2ms/step - loss: 4.1396e-04 - mae: 0.0176 - val_loss: 4.0406e-04 - val_mae: 0.0170
# Epoch 20/100
# 60/60 - 0s - 2ms/step - loss: 4.0853e-04 - mae: 0.0175 - val_loss: 3.8460e-04 - val_mae: 0.0171
# Epoch 21/100
# 60/60 - 0s - 2ms/step - loss: 3.9911e-04 - mae: 0.0174 - val_loss: 3.9659e-04 - val_mae: 0.0175
# Epoch 22/100
# 60/60 - 0s - 2ms/step - loss: 3.9669e-04 - mae: 0.0174 - val_loss: 3.8066e-04 - val_mae: 0.0170
# Epoch 23/100
# 60/60 - 0s - 2ms/step - loss: 3.9294e-04 - mae: 0.0173 - val_loss: 3.7413e-04 - val_mae: 0.0168
# Epoch 24/100
# 60/60 - 0s - 2ms/step - loss: 3.9005e-04 - mae: 0.0173 - val_loss: 3.7336e-04 - val_mae: 0.0170
# Epoch 25/100
# 60/60 - 0s - 2ms/step - loss: 3.8763e-04 - mae: 0.0173 - val_loss: 3.6997e-04 - val_mae: 0.0169
# Epoch 26/100
# 60/60 - 0s - 2ms/step - loss: 3.8413e-04 - mae: 0.0172 - val_loss: 3.6928e-04 - val_mae: 0.0167
# Epoch 27/100
# 60/60 - 0s - 2ms/step - loss: 3.8217e-04 - mae: 0.0171 - val_loss: 3.7267e-04 - val_mae: 0.0171
# Epoch 28/100
# 60/60 - 0s - 2ms/step - loss: 3.7785e-04 - mae: 0.0171 - val_loss: 3.6425e-04 - val_mae: 0.0165
# Epoch 29/100
# 60/60 - 0s - 2ms/step - loss: 3.7799e-04 - mae: 0.0171 - val_loss: 3.6282e-04 - val_mae: 0.0165
# Epoch 30/100
# 60/60 - 0s - 2ms/step - loss: 3.7643e-04 - mae: 0.0170 - val_loss: 3.6003e-04 - val_mae: 0.0167
# Epoch 31/100
# 60/60 - 0s - 2ms/step - loss: 3.7342e-04 - mae: 0.0170 - val_loss: 3.5979e-04 - val_mae: 0.0169
# Epoch 32/100
# 60/60 - 0s - 2ms/step - loss: 3.6938e-04 - mae: 0.0169 - val_loss: 3.5752e-04 - val_mae: 0.0169
# Epoch 33/100
# 60/60 - 0s - 2ms/step - loss: 3.7031e-04 - mae: 0.0170 - val_loss: 3.5841e-04 - val_mae: 0.0168
# Epoch 34/100
# 60/60 - 0s - 2ms/step - loss: 3.6478e-04 - mae: 0.0169 - val_loss: 3.5662e-04 - val_mae: 0.0169
# Epoch 35/100
# 60/60 - 0s - 2ms/step - loss: 3.6373e-04 - mae: 0.0168 - val_loss: 3.6613e-04 - val_mae: 0.0170
# Epoch 36/100
# 60/60 - 0s - 2ms/step - loss: 3.6596e-04 - mae: 0.0169 - val_loss: 3.5649e-04 - val_mae: 0.0169
# Epoch 37/100
# 60/60 - 0s - 2ms/step - loss: 3.6336e-04 - mae: 0.0169 - val_loss: 3.6026e-04 - val_mae: 0.0165
# Epoch 38/100
# 60/60 - 0s - 2ms/step - loss: 3.5960e-04 - mae: 0.0168 - val_loss: 3.5190e-04 - val_mae: 0.0168
# Epoch 39/100
# 60/60 - 0s - 2ms/step - loss: 3.6329e-04 - mae: 0.0169 - val_loss: 3.5315e-04 - val_mae: 0.0167
# Epoch 40/100
# 60/60 - 0s - 2ms/step - loss: 3.5982e-04 - mae: 0.0168 - val_loss: 3.5280e-04 - val_mae: 0.0167
# Epoch 41/100
# 60/60 - 0s - 2ms/step - loss: 3.5770e-04 - mae: 0.0167 - val_loss: 3.4857e-04 - val_mae: 0.0166
# Epoch 42/100
# 60/60 - 0s - 2ms/step - loss: 3.5665e-04 - mae: 0.0168 - val_loss: 3.4559e-04 - val_mae: 0.0167
# Epoch 43/100
# 60/60 - 0s - 2ms/step - loss: 3.5611e-04 - mae: 0.0168 - val_loss: 3.4300e-04 - val_mae: 0.0166
# Epoch 44/100
# 60/60 - 0s - 2ms/step - loss: 3.5540e-04 - mae: 0.0167 - val_loss: 3.4093e-04 - val_mae: 0.0165
# Epoch 45/100
# 60/60 - 0s - 2ms/step - loss: 3.5290e-04 - mae: 0.0167 - val_loss: 3.4184e-04 - val_mae: 0.0166
# Epoch 46/100
# 60/60 - 0s - 2ms/step - loss: 3.4916e-04 - mae: 0.0166 - val_loss: 3.4090e-04 - val_mae: 0.0167
# Epoch 47/100
# 60/60 - 0s - 2ms/step - loss: 3.4769e-04 - mae: 0.0166 - val_loss: 3.4111e-04 - val_mae: 0.0164
# Epoch 48/100
# 60/60 - 0s - 2ms/step - loss: 3.4820e-04 - mae: 0.0166 - val_loss: 3.5923e-04 - val_mae: 0.0167
# Epoch 49/100
# 60/60 - 0s - 2ms/step - loss: 3.4858e-04 - mae: 0.0166 - val_loss: 3.4142e-04 - val_mae: 0.0164
# Epoch 50/100
# 60/60 - 0s - 2ms/step - loss: 3.4872e-04 - mae: 0.0166 - val_loss: 3.3879e-04 - val_mae: 0.0164
# Epoch 51/100
# 60/60 - 0s - 2ms/step - loss: 3.4572e-04 - mae: 0.0166 - val_loss: 3.3440e-04 - val_mae: 0.0162
# Epoch 52/100
# 60/60 - 0s - 2ms/step - loss: 3.4353e-04 - mae: 0.0165 - val_loss: 3.3405e-04 - val_mae: 0.0164
# Epoch 53/100
# 60/60 - 0s - 2ms/step - loss: 3.4285e-04 - mae: 0.0165 - val_loss: 3.3408e-04 - val_mae: 0.0164
# Epoch 54/100
# 60/60 - 0s - 2ms/step - loss: 3.4456e-04 - mae: 0.0165 - val_loss: 3.4982e-04 - val_mae: 0.0164
# Epoch 55/100
# 60/60 - 0s - 2ms/step - loss: 3.4228e-04 - mae: 0.0165 - val_loss: 3.3050e-04 - val_mae: 0.0161
# Epoch 56/100
# 60/60 - 0s - 2ms/step - loss: 3.4216e-04 - mae: 0.0165 - val_loss: 3.3759e-04 - val_mae: 0.0161
# Epoch 57/100
# 60/60 - 0s - 2ms/step - loss: 3.3894e-04 - mae: 0.0164 - val_loss: 3.3351e-04 - val_mae: 0.0163
# Epoch 58/100
# 60/60 - 0s - 2ms/step - loss: 3.4008e-04 - mae: 0.0165 - val_loss: 3.2848e-04 - val_mae: 0.0160
# Epoch 59/100
# 60/60 - 0s - 2ms/step - loss: 3.3860e-04 - mae: 0.0164 - val_loss: 3.3181e-04 - val_mae: 0.0164
# Epoch 60/100
# 60/60 - 0s - 2ms/step - loss: 3.3826e-04 - mae: 0.0164 - val_loss: 3.2800e-04 - val_mae: 0.0162
# Epoch 61/100
# 60/60 - 0s - 2ms/step - loss: 3.3846e-04 - mae: 0.0164 - val_loss: 3.3178e-04 - val_mae: 0.0164
# Epoch 62/100
# 60/60 - 0s - 2ms/step - loss: 3.3483e-04 - mae: 0.0163 - val_loss: 3.2578e-04 - val_mae: 0.0162
# Epoch 63/100
# 60/60 - 0s - 2ms/step - loss: 3.3525e-04 - mae: 0.0164 - val_loss: 3.2478e-04 - val_mae: 0.0161
# Epoch 64/100
# 60/60 - 0s - 2ms/step - loss: 3.3369e-04 - mae: 0.0163 - val_loss: 3.2570e-04 - val_mae: 0.0163
# Epoch 65/100
# 60/60 - 0s - 2ms/step - loss: 3.3343e-04 - mae: 0.0163 - val_loss: 3.2391e-04 - val_mae: 0.0162
# Epoch 66/100
# 60/60 - 0s - 2ms/step - loss: 3.3155e-04 - mae: 0.0163 - val_loss: 3.2259e-04 - val_mae: 0.0160
# Epoch 67/100
# 60/60 - 0s - 2ms/step - loss: 3.3226e-04 - mae: 0.0163 - val_loss: 3.3269e-04 - val_mae: 0.0161
# Epoch 68/100
# 60/60 - 0s - 2ms/step - loss: 3.3022e-04 - mae: 0.0163 - val_loss: 3.3788e-04 - val_mae: 0.0162
# Epoch 69/100
# 60/60 - 0s - 2ms/step - loss: 3.3252e-04 - mae: 0.0163 - val_loss: 3.2088e-04 - val_mae: 0.0160
# Epoch 70/100
# 60/60 - 0s - 2ms/step - loss: 3.3013e-04 - mae: 0.0163 - val_loss: 3.2876e-04 - val_mae: 0.0160
# Epoch 71/100
# 60/60 - 0s - 2ms/step - loss: 3.2837e-04 - mae: 0.0162 - val_loss: 3.4214e-04 - val_mae: 0.0162
# Epoch 72/100
# 60/60 - 0s - 2ms/step - loss: 3.2950e-04 - mae: 0.0163 - val_loss: 3.2821e-04 - val_mae: 0.0162
# Epoch 73/100
# 60/60 - 0s - 2ms/step - loss: 3.2865e-04 - mae: 0.0162 - val_loss: 3.2507e-04 - val_mae: 0.0162
# Epoch 74/100
# 60/60 - 0s - 2ms/step - loss: 3.2864e-04 - mae: 0.0162 - val_loss: 3.3081e-04 - val_mae: 0.0163
# Epoch 75/100
# 60/60 - 0s - 2ms/step - loss: 3.2885e-04 - mae: 0.0162 - val_loss: 3.3319e-04 - val_mae: 0.0162
# Epoch 76/100
# 60/60 - 0s - 2ms/step - loss: 3.3040e-04 - mae: 0.0163 - val_loss: 3.2286e-04 - val_mae: 0.0159
# Epoch 77/100
# 60/60 - 0s - 2ms/step - loss: 3.2911e-04 - mae: 0.0162 - val_loss: 3.1778e-04 - val_mae: 0.0161
# Epoch 78/100
# 60/60 - 0s - 2ms/step - loss: 3.2698e-04 - mae: 0.0162 - val_loss: 3.1658e-04 - val_mae: 0.0158
# Epoch 79/100
# 60/60 - 0s - 2ms/step - loss: 3.2491e-04 - mae: 0.0162 - val_loss: 3.1527e-04 - val_mae: 0.0160
# Epoch 80/100
# 60/60 - 0s - 2ms/step - loss: 3.2453e-04 - mae: 0.0162 - val_loss: 3.1593e-04 - val_mae: 0.0159
# Epoch 81/100
# 60/60 - 0s - 2ms/step - loss: 3.2376e-04 - mae: 0.0161 - val_loss: 3.1876e-04 - val_mae: 0.0160
# Epoch 82/100
# 60/60 - 0s - 2ms/step - loss: 3.2251e-04 - mae: 0.0161 - val_loss: 3.1488e-04 - val_mae: 0.0158
# Epoch 83/100
# 60/60 - 0s - 2ms/step - loss: 3.2154e-04 - mae: 0.0161 - val_loss: 3.1590e-04 - val_mae: 0.0158
# Epoch 84/100
# 60/60 - 0s - 2ms/step - loss: 3.2379e-04 - mae: 0.0161 - val_loss: 3.2057e-04 - val_mae: 0.0159
# Epoch 85/100
# 60/60 - 0s - 2ms/step - loss: 3.2278e-04 - mae: 0.0161 - val_loss: 3.1670e-04 - val_mae: 0.0160
# Epoch 86/100
# 60/60 - 0s - 2ms/step - loss: 3.2176e-04 - mae: 0.0161 - val_loss: 3.1418e-04 - val_mae: 0.0160
# Epoch 87/100
# 60/60 - 0s - 2ms/step - loss: 3.1962e-04 - mae: 0.0160 - val_loss: 3.1198e-04 - val_mae: 0.0158
# Epoch 88/100
# 60/60 - 0s - 2ms/step - loss: 3.1838e-04 - mae: 0.0160 - val_loss: 3.1446e-04 - val_mae: 0.0158
# Epoch 89/100
# 60/60 - 0s - 2ms/step - loss: 3.1757e-04 - mae: 0.0160 - val_loss: 3.1313e-04 - val_mae: 0.0158
# Epoch 90/100
# 60/60 - 0s - 2ms/step - loss: 3.1973e-04 - mae: 0.0161 - val_loss: 3.1055e-04 - val_mae: 0.0159
# Epoch 91/100
# 60/60 - 0s - 2ms/step - loss: 3.1700e-04 - mae: 0.0160 - val_loss: 3.1235e-04 - val_mae: 0.0160
# Epoch 92/100
# 60/60 - 0s - 2ms/step - loss: 3.1970e-04 - mae: 0.0160 - val_loss: 3.0883e-04 - val_mae: 0.0158
# Epoch 93/100
# 60/60 - 0s - 2ms/step - loss: 3.1805e-04 - mae: 0.0160 - val_loss: 3.0945e-04 - val_mae: 0.0159
# Epoch 94/100
# 60/60 - 0s - 2ms/step - loss: 3.1638e-04 - mae: 0.0160 - val_loss: 3.1639e-04 - val_mae: 0.0159
# Epoch 95/100
# 60/60 - 0s - 2ms/step - loss: 3.1726e-04 - mae: 0.0160 - val_loss: 3.0825e-04 - val_mae: 0.0158
# Epoch 96/100
# 60/60 - 0s - 2ms/step - loss: 3.1672e-04 - mae: 0.0160 - val_loss: 3.1247e-04 - val_mae: 0.0157
# Epoch 97/100
# 60/60 - 0s - 2ms/step - loss: 3.1699e-04 - mae: 0.0160 - val_loss: 3.1726e-04 - val_mae: 0.0159
# Epoch 98/100
# 60/60 - 0s - 2ms/step - loss: 3.1575e-04 - mae: 0.0159 - val_loss: 3.0983e-04 - val_mae: 0.0158
# Epoch 99/100
# 60/60 - 0s - 2ms/step - loss: 3.1535e-04 - mae: 0.0160 - val_loss: 3.0947e-04 - val_mae: 0.0158
# Epoch 100/100
# 60/60 - 0s - 2ms/step - loss: 3.1549e-04 - mae: 0.0159 - val_loss: 3.0666e-04 - val_mae: 0.0158
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Error (MSE): 0.000303
